# %% [markdown]
# # Lab 1: Statistical Foundations & Classical Models
#
# ## Objective
# Apply concepts from Lecture 1 to the Air Passengers dataset:
# 1. Time Series Decomposition.
# 2. Testing for Stationarity (ADF Test).
# 3. Interpreting ACF and PACF plots.
# 4. Building and evaluating an ARIMA model.

# %%
import kagglehub
path = kagglehub.dataset_download("rakannimer/air-passengers", output_dir="dataset/")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: dataset/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings

warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['axes.grid'] = True 
# Load Data
df = pd.read_csv('dataset/AirPassengers.csv')
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)
df.columns = ['Passengers']

print(df.head())

# Plot Raw Data
ax = plt.subplot()
ax.plot(df.index, df['Passengers'])
ax.set_title("Monthly Air Passengers")
ax.set_xlabel("Time")
ax.set_ylabel("Passengers")
plt.tight_layout()
plt.show()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ### Part 2: Time Series Decomposition
# The "Megaphone Effect" (increasing variance) suggests a Multiplicative model.

# %%
decomposition = seasonal_decompose(df['Passengers'], model='multiplicative', period=12)

fig = decomposition.plot()
fig.set_size_inches(12, 8)
plt.show()

# %% [markdown]
# ### Part 3: Stationarity
# Check stationarity using the Augmented Dickey-Fuller (ADF) test.
# - H0: Data is Non-Stationary.
# - H1: Data is Stationary.

# %%
def adf_test(series):
    """ADF Reject Nulls When
    - Statistic < Critical Value(5%)
    - P-value < 0.05
    """
    result = adfuller(series, autolag='BIC')
    print(f'ADF Statistic: {result[0]:.4f}')
    print(f'p-value: {result[1]:.4f}')
    print(f"Critical Values:")
    for k, v in  result[4].items():
        print(f"{k}: {v:.4f}")
    if result[1] < 0.05 and result[0] < result[4]['5%']:
        print("Result: Data is STATIONARY (Reject H0)")
    else:
        print("Result: Data is NON-STATIONARY (Fail to reject H0)")


def kpss_test(series):
    """KPSS Reject Nulls When
    - Statistic > Critical Value(5%)
    - P-value < 0.05
    """
    result = kpss(series, regression='c', nlags='auto')
    print(f'KPSS Statistic: {result[0]:.4f}')
    print(f'p-value: {result[1]:.4f}')
    print(f"Critical Values:")
    for k, v in  result[3].items():
        print(f"{k}: {v:.4f}")
    
    if result[1] < 0.05 and result[0] > result[3]['5%']:
        print("Result: Data is NON-STATIONARY (Reject H0)")
    else:
        print("Result: Data is STATIONARY (Fail to reject H0)")

print("--- Raw Data Test ---")
adf_test(df['Passengers'])
print("-"*50)
kpss_test(df['Passengers'])
# Out:
# --- Raw Data Test ---
# ADF Statistic: 0.8154
# p-value: 0.9919
# Critical Values:
# 1%: -3.4817
# 5%: -2.8840
# 10%: -2.5788
# Result: Data is NON-STATIONARY (Fail to reject H0)
# --------------------------------------------------
# KPSS Statistic: 1.6513
# p-value: 0.0100
# Critical Values:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# Result: Data is NON-STATIONARY (Reject H0)

# %%
# Log transformation to stabilize variance
df['Log_Passengers'] = np.log(df['Passengers'])

# Differencing to stabilize mean
df['Log_Diff'] = df['Log_Passengers'].diff().dropna()

# Plot Transformed Data
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

axes[0].plot(df['Log_Passengers'])
axes[0].set_title('Log Transformed Data')

axes[1].plot(df['Log_Diff'])
axes[1].axhline(0, color='black', linestyle='--')
axes[1].set_title('Log Data After Differencing (d=1)')

plt.tight_layout()
plt.show()

print("--- Differenced Log Data Test ---")
adf_test(df['Log_Diff'].dropna())
print("-"*50)
print("--- Differenced Log Data Test ---")
kpss_test(df['Log_Diff'].dropna())
# Out:
# --- Differenced Log Data Test ---
# ADF Statistic: -3.0530
# p-value: 0.0302
# Critical Values:
# 1%: -3.4817
# 5%: -2.8840
# 10%: -2.5788
# Result: Data is STATIONARY (Reject H0)
# --------------------------------------------------
# --- Differenced Log Data Test ---
# KPSS Statistic: 0.0383
# p-value: 0.1000
# Critical Values:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# Result: Data is STATIONARY (Fail to reject H0)

# %% [markdown]
# ### Part 4: ACF & PACF
# Identify AR(p) and MA(q) terms using the stationary series.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

plot_acf(df['Log_Diff'].dropna(), lags=30, ax=ax1)
ax1.set_title('Autocorrelation Function (ACF)')

plot_pacf(df['Log_Diff'].dropna(), lags=30, ax=ax2)
ax2.set_title('Partial Autocorrelation Function (PACF)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part 5: ARIMA Modeling
# Split data and fit an ARIMA(1,1,1) baseline model on the Log-transformed data.

# %%
train_ratio = 0.8
last_train_index = int(len(df) * train_ratio)
train, test = df[:last_train_index], df[last_train_index:]
train.tail()
# Out:
#             Passengers  Log_Passengers  Log_Diff
# Month
# 1958-03-01         362        5.891644  0.129593
# 1958-04-01         348        5.852202 -0.039442
# 1958-05-01         363        5.894403  0.042200
# 1958-06-01         435        6.075346  0.180943
# 1958-07-01         491        6.196444  0.121098

# %%
model = ARIMA(train['Log_Passengers'], order=(1, 1, 0), seasonal_order=(1,1,1,12))
model_fit = model.fit()

print(model_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                     Log_Passengers   No. Observations:                  115
# Model:             ARIMA(1, 1, 0)x(1, 1, [1], 12)   Log Likelihood                 189.021
# Date:                            Wed, 25 Feb 2026   AIC                           -370.042
# Time:                                    01:28:19   BIC                           -359.542
# Sample:                                01-01-1949   HQIC                          -365.790
#                                      - 07-01-1958
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3026      0.078     -3.862      0.000      -0.456      -0.149
# ar.S.L12      -0.0757      0.206     -0.367      0.714      -0.480       0.329
# ma.S.L12      -0.5178      0.239     -2.169      0.030      -0.986      -0.050
# sigma2         0.0014      0.000      7.471      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.56
# Prob(Q):                              0.99   Prob(JB):                         0.76
# Heteroskedasticity (H):               0.25   Skew:                             0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast_result = model_fit.get_forecast(steps=len(test))
forecast_values_log = forecast_result.predicted_mean
conf_int_log = forecast_result.conf_int()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train['Log_Passengers'], label='Training Data')
plt.plot(test['Log_Passengers'], label='Actual Test Data', color='green')
plt.plot(test.index, forecast_values_log, label='Forecast', color='red', linestyle='--')
plt.fill_between(test.index, conf_int_log.iloc[:, 0], conf_int_log.iloc[:, 1], alpha=0.3,color='#000')

plt.title('ARIMA Forecast vs Actuals')
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(test['Log_Passengers'], forecast_values_log)
rmse = np.sqrt(mean_squared_error(test['Log_Passengers'], forecast_values_log))
mape = np.mean(np.abs((test['Log_Passengers'] - forecast_values_log) / test['Log_Passengers'])) * 100

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 0.03
# RMSE: 0.03
# MAPE: 0.46%

# %% [markdown]
# ## AutoARIMA

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dataset/AirPassengers.csv")

df.columns = ['Month', 'Passengers']
df['Log_Passengers'] = np.log(df['Passengers'])
df['Month'] = pd.to_datetime(df['Month'])
df = df.set_index('Month')
df.head()
# Out:
#             Passengers  Log_Passengers
# Month
# 1949-01-01         112        4.718499
# 1949-02-01         118        4.770685
# 1949-03-01         132        4.882802
# 1949-04-01         129        4.859812
# 1949-05-01         121        4.795791

# %%
train_ratio = 0.8
last_train_index = int(len(df) * train_ratio)
train, test = df[:last_train_index], df[last_train_index:]
train.tail()
# Out:
#             Passengers  Log_Passengers
# Month
# 1958-03-01         362        5.891644
# 1958-04-01         348        5.852202
# 1958-05-01         363        5.894403
# 1958-06-01         435        6.075346
# 1958-07-01         491        6.196444

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA
from statsforecast.arima import arima_string

pipeline = StatsForecast(
    models=[AutoARIMA(season_length=12)],
    freq='MS',
    n_jobs=-1
)
train_df = pd.DataFrame({'ds':train.index, 'y':train.Log_Passengers, 'unique_id':'train'})
test_df = pd.DataFrame({'ds':test.index, 'y':test.Log_Passengers, 'unique_id':'test'})

# %%
pipeline.fit(df=train_df)
arima_string(pipeline.fitted_[0, 0].model_)
# Out:
# 'ARIMA(2,0,0)(0,1,1)[12] with drift        '

# %%
forecast_df = pipeline.predict(h=len(test_df), level=[95])

# %%
mae = mean_absolute_error(test['Log_Passengers'], forecast_df['AutoARIMA'])
rmse = np.sqrt(mean_squared_error(test['Log_Passengers'], forecast_df['AutoARIMA']))
mape = np.mean(np.abs((test['Log_Passengers'] - forecast_df['AutoARIMA']) / test['Log_Passengers'])) * 100

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 0.08
# RMSE: 0.09
# MAPE: nan%

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['Log_Passengers'], label='Training Data')
plt.plot(test['Log_Passengers'], label='Actual Test Data', color='green')
plt.plot(test.index, forecast_df['AutoARIMA'], label='Forecast', color='red', linestyle='--')
plt.fill_between(test.index, forecast_df['AutoARIMA-lo-95'], forecast_df['AutoARIMA-hi-95'], alpha=0.3,color='#000')

plt.title('ARIMA Forecast vs Actuals')
plt.legend()
plt.show()
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.14.6-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting statsforecast
#   Using cached statsforecast-2.0.3-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Collecting numpy<3,>=1.22.3 (from statsmodels)
#   Using cached numpy-2.4.2-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pandas!=2.1.0,>=1.4 (from statsmodels)
#   Using cached pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting packaging>=21.3 (from statsmodels)
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting cloudpickle (from statsforecast)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting coreforecast>=0.0.12 (from statsforecast)
#   Using cached coreforecast-0.0.17-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting numba<0.60.0,>=0.58.0 (from statsforecast)
#   Using cached numba-0.59.1-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.43.0,>=0.41.0 (from statsforecast)
#   Using cached llvmlite-0.42.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Using cached scipy-1.15.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting tqdm (from statsforecast)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting fugue>=0.8.1 (from statsforecast)
#   Using cached fugue-0.9.7-py3-none-any.whl.metadata (18 kB)
# Collecting utilsforecast>=0.1.4 (from statsforecast)
#   Using cached utilsforecast-0.2.15-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3 (from statsforecast)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting triad>=1.0.1 (from fugue>=0.8.1->statsforecast)
#   Using cached triad-1.0.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting adagio>=0.2.6 (from fugue>=0.8.1->statsforecast)
#   Using cached adagio-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Collecting pandas!=2.1.0,>=1.4 (from statsmodels)
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy<3,>=1.22.3 (from statsmodels)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting pytz>=2020.1 (from pandas!=2.1.0,>=1.4->statsmodels)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas!=2.1.0,>=1.4->statsmodels)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting narwhals>=2.0 (from utilsforecast>=0.1.4->statsforecast)
#   Using cached narwhals-2.17.0-py3-none-any.whl.metadata (14 kB)
# Collecting colorama (from tqdm->statsforecast)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting pyarrow>=6.0.1 (from triad>=1.0.1->fugue>=0.8.1->statsforecast)
#   Using cached pyarrow-23.0.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting fsspec>=2022.5.0 (from triad>=1.0.1->fugue>=0.8.1->statsforecast)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Using cached statsmodels-0.14.6-cp311-cp311-win_amd64.whl (9.6 MB)
# Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached statsforecast-2.0.3-cp311-cp311-win_amd64.whl (275 kB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached coreforecast-0.0.17-cp311-cp311-win_amd64.whl (237 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached fugue-0.9.7-py3-none-any.whl (281 kB)
# Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Using cached llvmlite-0.42.0-cp311-cp311-win_amd64.whl (28.1 MB)
# Using cached numba-0.59.1-cp311-cp311-win_amd64.whl (2.6 MB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached scipy-1.15.3-cp311-cp311-win_amd64.whl (41.2 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached utilsforecast-0.2.15-py3-none-any.whl (40 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached adagio-0.2.6-py3-none-any.whl (19 kB)
# Using cached narwhals-2.17.0-py3-none-any.whl (444 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached triad-1.0.2-py3-none-any.whl (59 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached pyarrow-23.0.1-cp311-cp311-win_amd64.whl (27.5 MB)
# Installing collected packages: pytz, tzdata, threadpoolctl, six, pyparsing, pyarrow, pillow, packaging, numpy, narwhals, llvmlite, kiwisolver, fsspec, fonttools, cycler, colorama, cloudpickle, tqdm, scipy, python-dateutil, patsy, numba, coreforecast, contourpy, pandas, matplotlib, utilsforecast, triad, statsmodels, adagio, fugue, statsforecast
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.0
#     Uninstalling numpy-2.4.0:
#       Successfully uninstalled numpy-2.4.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
# Successfully installed adagio-0.2.6 cloudpickle-3.1.2 colorama-0.4.6 contourpy-1.3.3 coreforecast-0.0.17 cycler-0.12.1 fonttools-4.61.1 fsspec-2026.2.0 fugue-0.9.7 kiwisolver-1.4.9 llvmlite-0.42.0 matplotlib-3.10.8 narwhals-2.17.0 numba-0.59.1 numpy-1.26.4 packaging-26.0 pandas-2.3.3 patsy-1.0.2 pillow-12.1.1 pyarrow-23.0.1 pyparsing-3.3.2 python-dateutil-2.9.0.post0 pytz-2025.2 scipy-1.15.3 six-1.17.0 statsforecast-2.0.3 statsmodels-0.14.6 threadpoolctl-3.6.0 tqdm-4.67.3 triad-1.0.2 tzdata-2025.3 utilsforecast-0.2.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastembed 0.7.4 requires pillow<12.0,>=10.3.0; python_version >= "3.10" and python_version < "3.13", but you have pillow 12.1.1 which is incompatible.
# langchain-core 1.2.6 requires packaging<26.0.0,>=23.2.0, but you have packaging 26.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\abdel\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
