# %% [markdown]
# # LAB 2: Probability Distributions and Statistical Data Visualization
#
# In this lab you will use python to study the following topics:
#
# - How to sample from different distributions functions.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for different distributions functions.
# - Statistical data visualization using seaborn library

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np
from scipy import stats


# matplotlib library
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Problem 1
# a) Use the numpy function [numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate a standard Gaussian random variable $X$ (zero mean and unit variance).
#
# - Use histogram to plot the estimated PDF of the random variable $X$
# - Compute the true "analytical" PDF -using the equation- of $X$ . Plot the true PDF on the top of the histogram figure.
# - Calculate the sample mean and the sample variance.

# %% [markdown]
# ### True/Analytical PDF
# ![image.png](attachment:image.png)

# %% [markdown]
# ## using `numpy`

# %%
x = np.random.normal(size=100000)
sns.histplot(x, kde=True)
plt.show()

# %%
#type your code here:
sample_mean = np.mean(x)
sample_variance = np.var(x)
print(f"sample_mean: {sample_mean} \n sample_variance: {sample_variance}")
x = np.random.normal(size=100000)
sns.histplot(x, kde=True)
plt.show()
# Out:
# sample_mean: -0.004024343193888958
#  sample_variance: 0.9987485046054895

# %% [markdown]
# ## using `scipy`

# %%
#type your code here:
x = stats.norm.rvs(size=100000)
sample_mean = np.mean(x)
sample_variance = np.var(x)
print(f"sample_mean: {sample_mean} \n sample_variance: {sample_variance}")
sns.histplot(x, kde=True)
plt.show()
# Out:
# sample_mean: -0.0018470082163445807
#  sample_variance: 0.9979909317546691

# %% [markdown]
# - Compute the true "analytical" PDF using [scipy.stats.norm.pdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html). Plot the true PDF on the top of the histogram figure.
# - Compute the CDF using [scipy.stats.norm.cdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html), then plot it.

# %%
x = stats.norm.rvs(size=100000)
x_axis = np.linspace(np.min(x), np.max(x), 1000)
true_pdf = stats.norm.pdf(x_axis)
true_cdf = stats.norm.cdf(x_axis)
plt.figure(figsize=(10, 6))
plt.hist(x, bins=50, density=True, label='Histogram', alpha=0.5)
plt.plot(x_axis, true_pdf, 'r-', linewidth=2, label='PDF')
plt.plot(x_axis, true_cdf, 'orange', linewidth=2, label='CDF')
plt.legend()
plt.title("Histogram with Analytical PDF and CDF")
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# b) Repeat (a) for a Gaussian random variable $Y$ with $mean=3$ and $variance=4$.

# %%
#type your code here:
x = np.random.normal(size=100000 , loc = 3 , scale = 2)
print(f"mean  : {np.mean(x)} \nvariance : {np.var(x)}")
sns.histplot(x, kde=True)
plt.show()
# Out:
# mean  : 2.9975001613106427
# variance : 4.005011479899836

# %%
#type your code here:
x_axis = np.linspace(np.min(x), np.max(x), 1000)
true_pdf = stats.norm.pdf(x_axis , loc = 3 , scale = 2)
true_cdf = stats.norm.cdf(x_axis , loc = 3 , scale = 2)
plt.figure(figsize=(10, 6))
plt.hist(x, bins=50, density=True, label='Histogram', alpha=0.5)
plt.plot(x_axis, true_pdf, 'r-', linewidth=2, label='PDF')
plt.plot(x_axis, true_cdf, 'orange', linewidth=2, label='CDF')
plt.legend()
plt.title("Histogram with Analytical PDF and CDF")
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# C) Repeat (a) for an exponential random variable with $\lambda = 1$ using [numpy.random.exponential](https://numpy.org/doc/stable/reference/random/generated/numpy.random.exponential.html), and [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html#scipy.stats.expon)

# %%
#type your code here:
exp_random = np.random.exponential(scale=1, size=10000)
print(f"mean: {np.mean(exp_random)} \nvariance : {np.var(exp_random)}")
sns.histplot(exp_random, kde=True)
plt.show()
# Out:
# mean: 0.9916259205267215
# variance : 0.9917999738626786

# %%
#type your code here:
true_pdf = stats.expon.pdf(x_axis , scale=1)
true_cdf = stats.expon.cdf(x_axis , scale=1)
plt.figure(figsize=(10, 8))
plt.hist(exp_random , bins = 50 ,density=True, label='Histogram', alpha=0.5)
plt.plot(x_axis, true_pdf, 'r-', linewidth=2, label='PDF')
plt.plot(x_axis, true_cdf, 'orange', linewidth=2, label='CDF')
plt.xlim(0, 12)
plt.legend()
plt.title("Histogram with Analytical PDF and CDF")
plt.show()

# %% [markdown]
# d) Repeat (a) for an exponential random variable with $\lambda = 0.5$

# %%
#type your code here:
x = np.random.exponential(scale = 2 , size = 10000)
print(f"mean: {np.mean(x)} \n variance : {np.var(x)}")
sns.histplot(x, kde=True)
plt.show()
# Out:
# mean: 2.019521548970227
#  variance : 4.067063590446497

# %%
#type your code here:
x = np.random.normal(size=100000 , scale = 2)
true_pdf = stats.norm.pdf(x_axis , scale = 2)
true_cdf = stats.norm.cdf(x_axis , scale = 2)
plt.figure(figsize=(10, 6))
plt.hist(x, bins=50, density=True, label='Histogram', alpha=0.5)
plt.plot(x_axis, true_pdf, 'r-', linewidth=2, label='PDF')
plt.plot(x_axis, true_cdf, 'orange', linewidth=2, label='CDF')
plt.legend()
plt.title("Histogram with Analytical PDF and CDF")
plt.xlim(-10 , 10)
plt.show()

# %% [markdown]
# e) Repeat for an binomial random variable with $n = 5$ and $p = 0.5$

# %%
#type your code here:
binomial = np.random.binomial(n= 5 , p =0.5 , size = 1000)
print(f"mean : {np.mean(binomial)} \n variance : {np.var(binomial)}")
x_axis = np.arange(0, 6)
true_pmf = stats.binom.pmf(x_axis , n=5 , p=0.5)
plt.hist(binomial , bins = np.arange(5+2) , density=True , alpha=0.7 , label='Histogram' , edgecolor = "white")
plt.vlines(x_axis , 0 , true_pmf , colors='r' , lw=2 , label='PMF')
plt.legend()
plt.title("Histogram with Analytical PMF")
plt.show()
# Out:
# mean : 2.503
#  variance : 1.255991

# %%
#type your code here:
binomial = np.random.binomial(n= 5 , p =0.5 , size = 1000)
print(f"mean : {np.mean(binomial)} \n variance : {np.var(binomial)}")
x_axis = np.arange(0, 6)
true_pmf = stats.binom.pmf(x_axis , n=5 , p=0.5)
true_cdf = stats.binom.cdf(x_axis , n=5 , p=0.5)
plt.figure(figsize=(10, 6))
plt.vlines(x_axis , 0 , true_pmf , colors='r' , lw=2 , label='PMF')
plt.step(x_axis , true_cdf , where='post' , color='orange' , lw=2 , label='CDF')
plt.legend()
plt.show()
# Out:
# mean : 2.546
#  variance : 1.253884

# %% [markdown]
# f) Repeat for an binomial random variable with $n = 20$ and $p = 0.5$

# %%
#type your code here:
x = np.random.binomial(n=20 , p = 0.5 , size = 10000)
print(f"mean : {np.mean(x)} \n variance : {np.var(x)}")
x_axis = np.arange(0 , 21)
true_pmf = stats.binom.pmf(x_axis , n = 20 , p =  0.5)
plt.vlines(x_axis , 0 , true_pmf , colors='r' , lw=2 , label='PMF')
plt.hist(x , bins = np.arange(20+2) , density=True , alpha=0.7 , label='Histogram' , edgecolor = "white")
plt.show()
# Out:
# mean : 9.976
#  variance : 5.001224000000001

# %%
#type your code here:
pmf = stats.binom.pmf( np.arange(0,21) , n=20 , p=0.5)
cdf = stats.binom.cdf( np.arange(0,21) , n=20 , p=0.5)
plt.figure(figsize=(10,6))
plt.vlines( np.arange(0,21) ,0, pmf , alpha=0.7 , label='PMF' )
plt.step( np.arange(0,21) , cdf , where='post' , color='orange' , lw=2 , label='CDF' )
plt.legend()
plt.show()

# %% [markdown]
# # Problem 2
#
# (a) In this problem, you will use [seaborn](https://seaborn.pydata.org/) for statistical data visualization:
#
# - Load the penguins data `df = sns.load_dataset("penguins")`.
# - Display the first 5 rows of the dataset and use any relevant functions that can help you to understand the data.

# %%
df = sns.load_dataset("penguins")

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - Use seaborn different plots to explore the data.
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:
sns.pairplot(df , diag_kind='kde')

# %% [markdown]
# - [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) : `sns.heatmap(df.corr(), annot=True)`

# %%
#type your code here:
sns.heatmap(df.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:
sns.pairplot(df , hue ='species' , diag_kind='kde')

# %%
#type your code here:
sns.pairplot(df ,hue="sex" , diag_kind='kde')

# %%
#type your code here:
sns.pairplot(df , hue='island' , diag_kind='kde')

# %% [markdown]
# - [displot](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
#type your code here:
sns.displot(
    data=df,
    x='flipper_length_mm',
    col='species',
    row='sex',
    kind='hist',
    facet_kws={'margin_titles': True}
)

# %%
#type your code here:
sns.displot(data = df , x = 'flipper_length_mm' , col = "island" , row="sex" , kind = "hist",facet_kws={"margin_titles":True})

# %%
#type your code here:
sns.displot(data = df , x = 'flipper_length_mm' , col = "island" , row="species" , kind = "hist",facet_kws={"margin_titles":True})

# %% [markdown]
# - [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
#type your code here:
sns.jointplot(data = df , x = "bill_length_mm" , y="bill_depth_mm" , hue = "species")

# %%
#type your code here:
sns.jointplot(data = df , x = "bill_length_mm" , y="bill_depth_mm" ,kind = "hex")

# %% [markdown]
# - [swarmplot](https://seaborn.pydata.org/generated/seaborn.swarmplot.html)

# %%
#type your code here:
sns.swarmplot(data = df , x ="body_mass_g" , y = "sex" , hue="species")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %% [markdown]
# - [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
#type your code here:
sns.boxplot(
    data=df, 
    x="species", 
    y="body_mass_g", 
    hue="species"
)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# #### Another interesting examples:
#
# - https://seaborn.pydata.org/examples/marginal_ticks.html
# - https://seaborn.pydata.org/examples/layered_bivariate_plot.html
# - https://seaborn.pydata.org/examples/joint_kde.html
# - https://seaborn.pydata.org/examples/joint_histogram.html
# - https://seaborn.pydata.org/examples/jitter_stripplot.html
# - https://seaborn.pydata.org/examples/horizontal_boxplot.html

# %% [markdown]
# (b) Exploring iris data:

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# # Problem 3: Practicing the Central Limit Theorem
# Use Python to simulate the Central Limit Theorem for the following random i.i.d variables and check that the higher the number of number the variables, the more the mean of subsets behave like a gaussian random variable.

# %%
n_variables = 100
n_subsets = 10000
data = np.random.uniform(-1, 0, (n_subsets, n_variables))
subset_means = np.mean(data, axis=1)
plt.figure(figsize=(10, 6))
plt.hist(subset_means, bins=100, color='#1f77b4')  # Matplotlib default blue
plt.grid(True, alpha=0.5)
plt.title(f'Central Limit Theorem Simulation (N={n_variables})')
plt.xlabel('Mean of Subsets')
plt.ylabel('Frequency')
plt.show()
